# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
import os
import time
from crewai import Agent, Task, Crew, Process
from crewai_tools import tool

# %%
from typing import List
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %%
qdrant = QdrantClient(url="http://eager_cerf:6333")
encoder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
df = pd.read_csv("/home/jovyan/anaconda/nexis/dataset/Clean_Dataset.csv")
display(df.head())
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# ## add departure and arrival date

# %%
df.drop("arrival_time",axis=1,inplace=True)

# %%
df.drop("departure_time",axis=1,inplace=True)

# %%
df.rename(columns={'Unnamed: 0': 'id'}, inplace=True)

# %%
df.head()
# Out:
#    id   airline   flight source_city stops destination_city    class  \
# 0   0  SpiceJet  SG-8709       Delhi  zero           Mumbai  Economy
# 1   1  SpiceJet  SG-8157       Delhi  zero           Mumbai  Economy
# 2   2   AirAsia   I5-764       Delhi  zero           Mumbai  Economy
# 3   3   Vistara   UK-995       Delhi  zero           Mumbai  Economy
# 4   4   Vistara   UK-963       Delhi  zero           Mumbai  Economy
#
#    duration  days_left  price
# 0      2.17          1   5953
# 1      2.33          1   5953
# 2      2.17          1   5956
# 3      2.25          1   5955
# 4      2.33          1   5955

# %%
import random
from datetime import datetime, timedelta


dates = []

def random_date(start_date, end_date):
    delta = end_date - start_date
    random_days = random.randint(0, delta.days)
    random_seconds = random.randint(0, 24*3600 - 1)  
    return start_date + timedelta(days=random_days, seconds=random_seconds)

start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 7, 20)

for _ in range(300153):
    random_date_obj = random_date(start_date, end_date)
    random_date_str = random_date_obj.strftime("%Y-%m-%d %H:%M:%S")
    dates.append(random_date_str)

df['departure_date'] = dates
display(df.head())
# Out:
#    id   airline   flight source_city stops destination_city    class  \
# 0   0  SpiceJet  SG-8709       Delhi  zero           Mumbai  Economy
# 1   1  SpiceJet  SG-8157       Delhi  zero           Mumbai  Economy
# 2   2   AirAsia   I5-764       Delhi  zero           Mumbai  Economy
# 3   3   Vistara   UK-995       Delhi  zero           Mumbai  Economy
# 4   4   Vistara   UK-963       Delhi  zero           Mumbai  Economy
#
#    duration  days_left  price       departure_date
# 0      2.17          1   5953  2023-10-23 21:53:25
# 1      2.33          1   5953  2023-08-18 06:51:44
# 2      2.17          1   5956  2023-11-12 15:53:14
# 3      2.25          1   5955  2023-10-04 15:13:04
# 4      2.33          1   5955  2024-03-14 12:59:33

# %%
df['departure_date'] = pd.to_datetime(df['departure_date'])
df['arrival_date'] = df.apply(lambda row: row['departure_date'] + timedelta(hours=row['duration']), axis=1)

display(df.head())
# Out:
#    id   airline   flight source_city stops destination_city    class  \
# 0   0  SpiceJet  SG-8709       Delhi  zero           Mumbai  Economy
# 1   1  SpiceJet  SG-8157       Delhi  zero           Mumbai  Economy
# 2   2   AirAsia   I5-764       Delhi  zero           Mumbai  Economy
# 3   3   Vistara   UK-995       Delhi  zero           Mumbai  Economy
# 4   4   Vistara   UK-963       Delhi  zero           Mumbai  Economy
#
#    duration  days_left  price      departure_date        arrival_date
# 0      2.17          1   5953 2023-10-23 21:53:25 2023-10-24 00:03:37
# 1      2.33          1   5953 2023-08-18 06:51:44 2023-08-18 09:11:32
# 2      2.17          1   5956 2023-11-12 15:53:14 2023-11-12 18:03:26
# 3      2.25          1   5955 2023-10-04 15:13:04 2023-10-04 17:28:04
# 4      2.33          1   5955 2024-03-14 12:59:33 2024-03-14 15:19:21

# %% [markdown]
# ## split data

# %% [markdown]
# ### 1) Business vs Economy (based on airlines)

# %%
columns_1 = ['id', 'airline','class','price']

# %%
df_1 = df[columns_1]

# %%
df_1.head()
# Out:
#    id   airline    class  price
# 0   0  SpiceJet  Economy   5953
# 1   1  SpiceJet  Economy   5953
# 2   2   AirAsia  Economy   5956
# 3   3   Vistara  Economy   5955
# 4   4   Vistara  Economy   5955

# %%
# Define OpenAI environment variables
os.environ["OPENAI_API_BASE"] = 'https://api.groq.com/openai/v1'
os.environ["OPENAI_MODEL_NAME"] = 'llama3-70b-8192'
os.environ["OPENAI_API_KEY"] = "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"

# %%
def create_analyst_agent():
    analyst = Agent(
                    role='Veri Analisti',
                    goal='Verilen veri kümesi hakkında detaylı analiz yap ve veri ile ilgili bilgileri araştır.',
                    backstory="""
                    Sen uzman bir araştırmacısın. 
                    Araştırma yaparken İngilizce kullanıyorsun.
                    Teknik konulara hakimsin. 
                    Belirli bir veri kümesi hakkında derinlemesine bilgi toplaman gerekiyor.
                    """,
                    verbose=False,
                    allow_delegation=False
                    )
      
        return analyst

def create_write_agent():
    writer = Agent(
                    role='Raporlayıcı',
                    goal='Araştırmacının sağladığı bilgileri kullanarak en yüksek geliri elde edebilmek için uçak fiyatları nasıl belirlenmelidir hangi parametreler daha etkilidir yorumlamalar yap.',
                    backstory="""
                    Sen uzman bir fiyat raporlayıcısısın. 
                    Teknik konulara hakimsin. 
                    Teknik ve bilgilendirici içerik üretmek senin uzmanlık alanın.
                    Olabildiğince kısa ve anlaşılır cümleler kuruyorsun.
                    Eğer kullanacağın bilgilerde eksikler varsa, araştırmacıya soruyorsun.
                    """,
                    verbose=False,
                    allow_delegation=False  

                    )
        return writer

# %%
def create_research_task(analyst,df):
    research_task = Task(
                        description=f"""Verilen veri kümesi ({df}) hakkında detaylı analiz yap ve konuyu araştır.""",
                        expected_output='Mevsim, uçak tipi , uçuş süresi gibi değişkenlerle fiyatlar arasındaki ilişkinin yorumlanması',
                        agent=analyst,
                        verbose=False
                        )
        
    return research_task
    
def create_write_task(writer,expected_output):
    write_task = Task(
                    description=f"""Araştırmacının sağladığı bilgileri kullanarak bilgilendirici ve uzman diliyle yazılmış bir açıklama metini yaz. 
                    Metin, her değişken arasındaki ilişki için olası optimal fiyat aralıklarını vermeli ve sebeplerini açıklamalıdır.
                    """,
                    expected_output = expected_output,
                    agent=writer,
                    verbose=False
                    )
        
        return write_task

# %%
# Define agents
analyst = Agent(
    role='Veri Analisti',
    goal='Verilen veri kümesi hakkında detaylı analiz yap ve veri ile ilgili bilgileri araştır.',
    backstory="""
    Sen uzman bir araştırmacısın. 
    Araştırma yaparken İngilizce kullanıyorsun.
    Teknik konulara hakimsin. 
    Belirli bir veri kümesi hakkında derinlemesine bilgi toplaman gerekiyor.
    """,
    verbose=False,
    allow_delegation=False
)

writer = Agent(
    role='Raporlayıcı',
    goal='Araştırmacının sağladığı bilgileri kullanarak en yüksek geliri elde edebilmek için business ve ekonomi class fiyatları airline baz alınarak nasıl belirlenmeli ve ortalama fiyat ne kadar  olamalı ,nasıl belirlenmelidir açıkla.',
    backstory="""
    Sen uzman bir fiyat raporlayıcısısın. 
    Teknik konulara hakimsin. 
    Teknik ve bilgilendirici içerik üretmek senin uzmanlık alanın.
    Olabildiğince kısa ve anlaşılır cümleler kuruyorsun.
    Eğer kullanacağın bilgilerde eksikler varsa, araştırmacıya soruyorsun.
    """,
    verbose=False,
    allow_delegation=False 
)

# Define tasks
research_task = Task(
    description=f"""Verilen veri kümesi ({df_1.head()}) hakkında detaylı analiz yap ve konuyu araştır.""",
    expected_output='airline , class tipi ve  fiyatlar arasındaki ilişkinin yorumlanması',
    agent=analyst,
    verbose=False
)

write_task = Task(
    description=f"""Araştırmacının sağladığı bilgileri kullanarak bilgilendirici ve uzman diliyle yazılmış bir açıklama metini yaz. 
    Metin, her değişken arasındaki ilişki için olası optimal fiyat aralıklarını vermeli ve sebeplerini açıklamalıdır.
    """,
    expected_output='En yüksek kar için uçuş sınıfı,airline ve fiyat gibi parametrelere bakarak optimal fiyat aralıklarını belirlemelidir.',
    agent=writer,
    verbose=False
)

# Create the CrewAI team
crew = Crew(
    agents=[analyst, writer],
    tasks=[research_task, write_task],
    verbose=0,
    process=Process.sequential  
)


result = crew.kickoff()

# %%
result
# Out:
# 'To maximize revenue, it is essential to determine the optimal price range for economy-class flights across airlines. Based on the analysis, the following insights can be used to determine the optimal price range:\n\n**Airline Factor:**\nSince there is no significant price difference between SpiceJet, AirAsia, and Vistara for economy-class flights, the airline factor can be considered neutral. This means that the optimal price range will not be significantly affected by the airline chosen.\n\n**Class Factor:**\nThe dataset only represents economy-class flights, which eliminates the need to consider other classes. Therefore, the class factor can be considered constant.\n\n**Price Factor:**\nThe prices range from 5953 to 5956, with a mean price of 5954.4 and a standard deviation of 1.14. This narrow range suggests that the optimal price range should be focused around the mean price.\n\nConsidering these factors, the optimal price range for economy-class flights across airlines can be determined as follows:\n\nThe lower bound of the optimal price range can be set at 5953, which is the minimum observed price in the dataset. This ensures that the airline is competitive with other airlines and attracts price-sensitive customers.\n\nThe upper bound of the optimal price range can be set at 5956, which is the maximum observed price in the dataset. This allows the airline to capitalize on customers who are willing to pay a premium for their flights.\n\nThe optimal price point can be set at 5954.4, which is the mean price of the dataset. This price point is likely to appeal to the majority of customers and provide a balance between revenue and demand.\n\nIn conclusion, the optimal price range for economy-class flights across airlines is between 5953 and 5956, with an optimal price point of 5954.4. This price range takes into account the neutral airline factor, constant class factor, and the narrow price range observed in the dataset.\n\nBy setting prices within this range, airlines can maximize revenue while remaining competitive in the market. However, it is essential to note that this analysis is based on a limited dataset and may not be representative of the entire market. Further analysis with a larger dataset would be necessary to draw more robust conclusions.'

# %%
# Creating collections and defining vector parameters
qdrant.create_collection(
        collection_name="flights",
        vectors_config=models.VectorParams(
            size=encoder.get_sentence_embedding_dimension(),
            distance=models.Distance.COSINE
        )
)

# %%
# Loading points process
text = result
points = [
    models.PointStruct(
        id=0,
        vector=encoder.encode(text).tolist(),
        payload={"description": text}
    )
]

qdrant.upload_points(
    collection_name="flights",
    points=points,
    batch_size=64,
    parallel=1,
    method=None,
    max_retries=3,
    wait=False
)

# %%
# Semantic search operations
query_vector = encoder.encode("Flight Duration").tolist()
hits = qdrant.search(
    collection_name="flights",
    query_vector=query_vector,
    limit=3
)
for hit in hits:
    print(hit.payload, "score:", hit.score)
# Out:
# {'description': 'To maximize revenue, it is essential to determine the optimal price range for economy-class flights across airlines. Based on the analysis, the following insights can be used to determine the optimal price range:\n\n**Airline Factor:**\nSince there is no significant price difference between SpiceJet, AirAsia, and Vistara for economy-class flights, the airline factor can be considered neutral. This means that the optimal price range will not be significantly affected by the airline chosen.\n\n**Class Factor:**\nThe dataset only represents economy-class flights, which eliminates the need to consider other classes. Therefore, the class factor can be considered constant.\n\n**Price Factor:**\nThe prices range from 5953 to 5956, with a mean price of 5954.4 and a standard deviation of 1.14. This narrow range suggests that the optimal price range should be focused around the mean price.\n\nConsidering these factors, the optimal price range for economy-class flights across airlines can be determined as follows:\n\nThe lower bound of the optimal price range can be set at 5953, which is the minimum observed price in the dataset. This ensures that the airline is competitive with other airlines and attracts price-sensitive customers.\n\nThe upper bound of the optimal price range can be set at 5956, which is the maximum observed price in the dataset. This allows the airline to capitalize on customers who are willing to pay a premium for their flights.\n\nThe optimal price point can be set at 5954.4, which is the mean price of the dataset. This price point is likely to appeal to the majority of customers and provide a balance between revenue and demand.\n\nIn conclusion, the optimal price range for economy-class flights across airlines is between 5953 and 5956, with an optimal price point of 5954.4. This price range takes into account the neutral airline factor, constant class factor, and the narrow price range observed in the dataset.\n\nBy setting prices within this range, airlines can maximize revenue while remaining competitive in the market. However, it is essential to note that this analysis is based on a limited dataset and may not be representative of the entire market. Further analysis with a larger dataset would be necessary to draw more robust conclusions.'} score: 0.33208737

# %%
text = 'To maximize revenue, it is essential to determine the optimal price range for economy-class flights across airlines. Based on the analysis, the following insights can be used to determine the optimal price range:\n\n**Airline Factor:**\nSince there is no significant price difference between SpiceJet, AirAsia, and Vistara for economy-class flights, the airline factor can be considered neutral. This means that the optimal price range will not be significantly affected by the airline chosen.\n\n**Class Factor:**\nThe dataset only represents economy-class flights, which eliminates the need to consider other classes. Therefore, the class factor can be considered constant.\n\n**Price Factor:**\nThe prices range from 5953 to 5956, with a mean price of 5954.4 and a standard deviation of 1.14. This narrow range suggests that the optimal price range should be focused around the mean price.\n\nConsidering these factors, the optimal price range for economy-class flights across airlines can be determined as follows:\n\nThe lower bound of the optimal price range can be set at 5953, which is the minimum observed price in the dataset. This ensures that the airline is competitive with other airlines and attracts price-sensitive customers.\n\nThe upper bound of the optimal price range can be set at 5956, which is the maximum observed price in the dataset. This allows the airline to capitalize on customers who are willing to pay a premium for their flights.\n\nThe optimal price point can be set at 5954.4, which is the mean price of the dataset. This price point is likely to appeal to the majority of customers and provide a balance between revenue and demand.\n\nIn conclusion, the optimal price range for economy-class flights across airlines is between 5953 and 5956, with an optimal price point of 5954.4. This price range takes into account the neutral airline factor, constant class factor, and the narrow price range observed in the dataset.\n\nBy setting prices within this range, airlines can maximize revenue while remaining competitive in the market. However, it is essential to note that this analysis is based on a limited dataset and may not be representative of the entire market. Further analysis with a larger dataset would be necessary to draw more robust conclusions.'

# %%
# Define OpenAI environment variables
os.environ["OPENAI_API_BASE"] = 'https://api.groq.com/openai/v1'
os.environ["OPENAI_MODEL_NAME"] = 'llama3-70b-8192'
os.environ["OPENAI_API_KEY"] = "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"


# Define agents
analyst = Agent(
    role='Veri Analisti',
    goal='Verilen veri kümesi hakkında detaylı analiz yap ve veri ile ilgili bilgileri araştır.',
    backstory="""
    Sen uzman bir araştırmacısın. 
    Araştırma yaparken İngilizce kullanıyorsun.
    Teknik konulara hakimsin. 
    Belirli bir veri kümesi hakkında derinlemesine bilgi toplaman gerekiyor.
    """,
    verbose=False,
    allow_delegation=False
)

writer = Agent(
    role='Raporlayıcı',
    goal='Araştırmacının sağladığı bilgileri kullanarak en yüksek geliri elde edebilmek için business ve ekonomi class fiyatları airline baz alınarak nasıl belirlenmeli ve ortalama fiyat ne kadar  olamalı ,nasıl belirlenmelidir açıkla.',
    backstory="""
    Sen uzman bir fiyat raporlayıcısısın. 
    Teknik konulara hakimsin. 
    Teknik ve bilgilendirici içerik üretmek senin uzmanlık alanın.
    Olabildiğince kısa ve anlaşılır cümleler kuruyorsun.
    Eğer kullanacağın bilgilerde eksikler varsa, araştırmacıya soruyorsun.
    """,
    verbose=False,
    allow_delegation=False 
)

# Define tasks
research_task = Task(
    description=f"""Verilen veri kümesi ({df_1.head()}) hakkında detaylı analiz yap ve konuyu araştır.""",
    expected_output='airline , class tipi ve  fiyatlar arasındaki ilişkinin yorumlanması',
    agent=analyst,
    verbose=False
)

write_task = Task(
    description=f"""Araştırmacının sağladığı bilgileri kullanarak bilgilendirici ve uzman diliyle yazılmış bir açıklama metini yaz. 
    Metin, her değişken arasındaki ilişki için olası optimal fiyat aralıklarını vermeli ve sebeplerini açıklamalıdır.
    """,
    expected_output=text,
    agent=writer,
    verbose=False
)

# Create the CrewAI team
crew = Crew(
    agents=[analyst, writer],
    tasks=[research_task, write_task],
    verbose=0,
    process=Process.sequential  
)


result = crew.kickoff()

# %%
result
# Out:
# 'To maximize revenue, it is essential to determine the optimal price range for economy-class flights across airlines. Based on the analysis, the following insights can be used to determine the optimal price range:\n\n**Airline Factor:**\nSince there is no significant price difference between SpiceJet, AirAsia, and Vistara for economy-class flights, the airline factor can be considered neutral. This means that the optimal price range will not be significantly affected by the airline chosen.\n\n**Class Factor:**\nThe dataset only represents economy-class flights, which eliminates the need to consider other classes. Therefore, the class factor can be considered constant.\n\n**Price Factor:**\nThe prices range from 5953 to 5956, with a mean price of 5954.2 and a standard deviation of 1.581. This narrow range suggests that the optimal price range should be focused around the mean price.\n\nConsidering these factors, the optimal price range for economy-class flights across airlines can be determined as follows:\n\nThe lower bound of the optimal price range can be set at 5953, which is the minimum observed price in the dataset. This ensures that the airline is competitive with other airlines and attracts price-sensitive customers.\n\nThe upper bound of the optimal price range can be set at 5956, which is the maximum observed price in the dataset. This allows the airline to capitalize on customers who are willing to pay a premium for their flights.\n\nThe optimal price point can be set at 5954.2, which is the mean price of the dataset. This price point is likely to appeal to the majority of customers and provide a balance between revenue and demand.\n\nIn conclusion, the optimal price range for economy-class flights across airlines is between 5953 and 5956, with an optimal price point of 5954.2. This price range takes into account the neutral airline factor, constant class factor, and the narrow price range observed in the dataset.\n\nBy setting prices within this range, airlines can maximize revenue while remaining competitive in the market. However, it is essential to note that this analysis is based on a limited dataset and may not be representative of the entire market. Further analysis with a larger dataset would be necessary to draw more robust conclusions.'

# %%
text = [hit.payload.get('description', '') for hit in hits][0]

# %%
text
# Out:
# 'To maximize revenue, it is essential to determine the optimal price range for economy-class flights across airlines. Based on the analysis, the following insights can be used to determine the optimal price range:\n\n**Airline Factor:**\nSince there is no significant price difference between SpiceJet, AirAsia, and Vistara for economy-class flights, the airline factor can be considered neutral. This means that the optimal price range will not be significantly affected by the airline chosen.\n\n**Class Factor:**\nThe dataset only represents economy-class flights, which eliminates the need to consider other classes. Therefore, the class factor can be considered constant.\n\n**Price Factor:**\nThe prices range from 5953 to 5956, with a mean price of 5954.4 and a standard deviation of 1.14. This narrow range suggests that the optimal price range should be focused around the mean price.\n\nConsidering these factors, the optimal price range for economy-class flights across airlines can be determined as follows:\n\nThe lower bound of the optimal price range can be set at 5953, which is the minimum observed price in the dataset. This ensures that the airline is competitive with other airlines and attracts price-sensitive customers.\n\nThe upper bound of the optimal price range can be set at 5956, which is the maximum observed price in the dataset. This allows the airline to capitalize on customers who are willing to pay a premium for their flights.\n\nThe optimal price point can be set at 5954.4, which is the mean price of the dataset. This price point is likely to appeal to the majority of customers and provide a balance between revenue and demand.\n\nIn conclusion, the optimal price range for economy-class flights across airlines is between 5953 and 5956, with an optimal price point of 5954.4. This price range takes into account the neutral airline factor, constant class factor, and the narrow price range observed in the dataset.\n\nBy setting prices within this range, airlines can maximize revenue while remaining competitive in the market. However, it is essential to note that this analysis is based on a limited dataset and may not be representative of the entire market. Further analysis with a larger dataset would be necessary to draw more robust conclusions.'

# %% [markdown]
# ### 2) Business vs Economy (based on duration)

# %%
columns_2 = ['id', 'duration','class','price']

# %%
df_2 = df[columns_2]

# %%
df_2.head()
# Out:
#    id  duration    class  price
# 0   0      2.17  Economy   5953
# 1   1      2.33  Economy   5953
# 2   2      2.17  Economy   5956
# 3   3      2.25  Economy   5955
# 4   4      2.33  Economy   5955

# %%
# Define OpenAI environment variables
os.environ["OPENAI_API_BASE"] = 'https://api.groq.com/openai/v1'
os.environ["OPENAI_MODEL_NAME"] = 'llama3-70b-8192'
os.environ["OPENAI_API_KEY"] = "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"


# Define agents
analyst = Agent(
    role='Veri Analisti',
    goal='Verilen veri kümesi hakkında detaylı analiz yap ve veri ile ilgili bilgileri araştır.',
    backstory="""
    Sen uzman bir araştırmacısın. 
    Araştırma yaparken İngilizce kullanıyorsun.
    Teknik konulara hakimsin. 
    Belirli bir veri kümesi hakkında derinlemesine bilgi toplaman gerekiyor.
    """,
    verbose=False,
    allow_delegation=False
)

writer = Agent(
    role='Raporlayıcı',
    goal='Araştırmacının sağladığı bilgileri kullanarak en yüksek geliri elde edebilmek için business ve ekonomi class fiyatları duration baz alınarak nasıl belirlenmeli ve ortalama fiyat ne kadar  olamalı ,nasıl belirlenmelidir açıkla.',
    backstory="""
    Sen uzman bir fiyat raporlayıcısısın. 
    Teknik konulara hakimsin. 
    Teknik ve bilgilendirici içerik üretmek senin uzmanlık alanın.
    Olabildiğince kısa ve anlaşılır cümleler kuruyorsun.
    Eğer kullanacağın bilgilerde eksikler varsa, araştırmacıya soruyorsun.
    """,
    verbose=False,
    allow_delegation=False 
)

# Define tasks
research_task = Task(
    description=f"""Verilen veri kümesi ({df_2.head()}) hakkında detaylı analiz yap ve konuyu araştır.""",
    expected_output='duration , class tipi ve  fiyatlar arasındaki ilişkinin yorumlanması',
    agent=analyst,
    verbose=False
)

write_task = Task(
    description=f"""Araştırmacının sağladığı bilgileri kullanarak bilgilendirici ve uzman diliyle yazılmış bir açıklama metini yaz. 
    Metin, istenen değişkenler ilişki için olası optimal fiyat aralıklarını vermeli ve sebeplerini açıklamalıdır.
    """,
    expected_output='En yüksek kar için uçuş sınıfı,duration ve fiyat gibi parametrelere bakarak optimal fiyat aralıklarını belirlemelidir.',
    agent=writer,
    verbose=False
)

# Create the CrewAI team
crew = Crew(
    agents=[analyst, writer],
    tasks=[research_task, write_task],
    verbose=0,
    process=Process.sequential  
)


result = crew.kickoff()

# %%
result
# Out:
# "**Optimal Price Ranges for Maximum Profit: A Data-Driven Approach**\n\nIn order to determine the optimal price ranges for maximum profit, it is essential to analyze the relationships between the variables `duration`, `class`, and `price`. Based on the given dataset, a weak positive relationship exists between `duration` and `price`, suggesting that longer durations are associated with slightly higher prices. However, the correlation is relatively weak, and other factors may be influencing the relationship.\n\nTo maximize profit, we need to identify the optimal price ranges for each class and duration combination. Since the `class` variable is not informative in this analysis, we will focus on the `duration` variable.\n\n**Duration-Based Pricing**\n\nTo determine the optimal price ranges for each duration, we can analyze the distribution of prices for each duration group. By doing so, we can identify the price ranges that correspond to the highest profit margins.\n\nFor example, let's assume we have three duration groups: short (0-2 hours), medium (2-4 hours), and long (4-6 hours). By analyzing the price distribution for each group, we can determine the optimal price ranges as follows:\n\n* Short duration (0-2 hours): $50-$70\n* Medium duration (2-4 hours): $80-$110\n* Long duration (4-6 hours): $120-$150\n\n**Pricing Strategy**\n\nTo maximize profit, we can adopt a dynamic pricing strategy that takes into account the duration and demand for each flight. During peak demand periods, we can adjust the prices to the upper end of the optimal range, and during off-peak periods, we can adjust the prices to the lower end of the optimal range.\n\n**Average Price Calculation**\n\nTo calculate the average price for each class, we can use the following formula:\n\nAverage Price = (Sum of Prices) / (Number of Flights)\n\nBy using this formula, we can calculate the average price for each class and duration combination, which will help us to identify the optimal price ranges for maximum profit.\n\n**Conclusion**\n\nIn conclusion, by analyzing the relationships between the variables `duration`, `class`, and `price`, we can determine the optimal price ranges for maximum profit. By adopting a dynamic pricing strategy that takes into account the duration and demand for each flight, we can maximize our profit margins. The optimal price ranges for each duration group are: short duration ($50-$70), medium duration ($80-$110), and long duration ($120-$150). By calculating the average price for each class and duration combination, we can refine our pricing strategy and achieve maximum profit."

# %%
# Loading points process
text = result
points = [
    models.PointStruct(
        id=0,
        vector=encoder.encode(text).tolist(),
        payload={"description": text}
    )
]

qdrant.upload_points(
    collection_name="flights",
    points=points,
    batch_size=64,
    parallel=1,
    method=None,
    max_retries=3,
    wait=False
)

# %%
# Semantic search operations
query_vector = encoder.encode("Flight Duration").tolist()
hits = qdrant.search(
    collection_name="flights",
    query_vector=query_vector,
    limit=3
)
for hit in hits:
    print(hit.payload, "score:", hit.score)
# Out:
# {'description': "**Optimal Price Ranges for Maximum Profit: A Data-Driven Approach**\n\nIn order to determine the optimal price ranges for maximum profit, it is essential to analyze the relationships between the variables `duration`, `class`, and `price`. Based on the given dataset, a weak positive relationship exists between `duration` and `price`, suggesting that longer durations are associated with slightly higher prices. However, the correlation is relatively weak, and other factors may be influencing the relationship.\n\nTo maximize profit, we need to identify the optimal price ranges for each class and duration combination. Since the `class` variable is not informative in this analysis, we will focus on the `duration` variable.\n\n**Duration-Based Pricing**\n\nTo determine the optimal price ranges for each duration, we can analyze the distribution of prices for each duration group. By doing so, we can identify the price ranges that correspond to the highest profit margins.\n\nFor example, let's assume we have three duration groups: short (0-2 hours), medium (2-4 hours), and long (4-6 hours). By analyzing the price distribution for each group, we can determine the optimal price ranges as follows:\n\n* Short duration (0-2 hours): $50-$70\n* Medium duration (2-4 hours): $80-$110\n* Long duration (4-6 hours): $120-$150\n\n**Pricing Strategy**\n\nTo maximize profit, we can adopt a dynamic pricing strategy that takes into account the duration and demand for each flight. During peak demand periods, we can adjust the prices to the upper end of the optimal range, and during off-peak periods, we can adjust the prices to the lower end of the optimal range.\n\n**Average Price Calculation**\n\nTo calculate the average price for each class, we can use the following formula:\n\nAverage Price = (Sum of Prices) / (Number of Flights)\n\nBy using this formula, we can calculate the average price for each class and duration combination, which will help us to identify the optimal price ranges for maximum profit.\n\n**Conclusion**\n\nIn conclusion, by analyzing the relationships between the variables `duration`, `class`, and `price`, we can determine the optimal price ranges for maximum profit. By adopting a dynamic pricing strategy that takes into account the duration and demand for each flight, we can maximize our profit margins. The optimal price ranges for each duration group are: short duration ($50-$70), medium duration ($80-$110), and long duration ($120-$150). By calculating the average price for each class and duration combination, we can refine our pricing strategy and achieve maximum profit."} score: 0.28407836

# %% [markdown]
# ## 3)Departure Date

# %%
columns_3 = ['id', 'departure_date','price']

# %%
df_3 = df[columns_3]

# %%
# Define OpenAI environment variables
os.environ["OPENAI_API_BASE"] = 'https://api.groq.com/openai/v1'
os.environ["OPENAI_MODEL_NAME"] = 'llama3-70b-8192'
os.environ["OPENAI_API_KEY"] = "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"


# Define agents
analyst = Agent(
    role='Veri Analisti',
    goal='Verilen veri kümesi hakkında detaylı analiz yap ve veri ile ilgili bilgileri araştır.',
    backstory="""
    Sen uzman bir araştırmacısın. 
    Araştırma yaparken İngilizce kullanıyorsun.
    Teknik konulara hakimsin. 
    Belirli bir veri kümesi hakkında derinlemesine bilgi toplaman gerekiyor.
    """,
    verbose=False,
    allow_delegation=False
)

writer = Agent(
    role='Raporlayıcı',
    goal='Araştırmacının sağladığı bilgileri kullanarak en yüksek geliri elde edebilmek için departure date baz alınarak nasıl belirlenmeli ve ortalama fiyat ne kadar  olamalı ,nasıl belirlenmelidir açıkla.',
    backstory="""
    Sen uzman bir fiyat raporlayıcısısın. 
    Teknik konulara hakimsin. 
    Teknik ve bilgilendirici içerik üretmek senin uzmanlık alanın.
    Olabildiğince kısa ve anlaşılır cümleler kuruyorsun.
    Eğer kullanacağın bilgilerde eksikler varsa, araştırmacıya soruyorsun.
    """,
    verbose=False,
    allow_delegation=False 
)

# Define tasks
research_task = Task(
    description=f"""Verilen veri kümesi ({df_3.head()}) hakkında detaylı analiz yap ve konuyu araştır.""",
    expected_output='departure date ve  fiyatlar arasındaki ilişkinin yorumlanması',
    agent=analyst,
    verbose=False
)

write_task = Task(
    description=f"""Araştırmacının sağladığı bilgileri kullanarak bilgilendirici ve uzman diliyle yazılmış bir açıklama metini yaz. 
    Metin, istenilen değişkenler arasındaki ilişki için olası optimal fiyat aralıklarını vermeli ve sebeplerini açıklamalıdır.
    """,
    expected_output='En yüksek kar için departure date ve fiyat gibi parametrelere bakarak optimal fiyat aralıklarını belirlemelidir.',
    agent=writer,
    verbose=False
)

# Create the CrewAI team
crew = Crew(
    agents=[analyst, writer],
    tasks=[research_task, write_task],
    verbose=0,
    process=Process.sequential  
)


result = crew.kickoff()

# %%
result
# Out:
# 'Based on the analysis of the provided dataset, I conclude that to optimize pricing strategies, airlines should consider the following optimal price ranges for different departure date periods:\n\n**Winter Period (December 2023 to February 2024)**:\nThe optimal price range for this period is between 5953 and 5955, with a mean price of 5954.1. This is due to the lower demand during winter, resulting in lower prices.\n\n**Summer Period (June 2023 to July 2024)**:\nThe optimal price range for this period is between 5955 and 5956, with a mean price of 5955.5. This is due to the higher demand during summer, resulting in slightly higher prices.\n\nThe reasons for these optimal price ranges are attributed to the seasonal demand, school and holiday schedules, and weather and climate factors. By understanding these factors, airlines can adjust their pricing strategies to maximize revenue and respond to market fluctuations.\n\nTo achieve the highest profit, airlines should consider dynamic pricing, targeted promotions, and segmentation strategies. By doing so, they can capitalize on the seasonal demand and customer needs, ultimately leading to increased revenue and competitiveness in the market.\n\nIn conclusion, the optimal price ranges for different departure date periods are crucial in determining the pricing strategies of airlines. By understanding the relationship between departure dates and prices, airlines can refine their strategies to better respond to market fluctuations and customer needs, ultimately leading to increased revenue and competitiveness.'

# %%
# Loading points process
text = result
points = [
    models.PointStruct(
        id=0,
        vector=encoder.encode(text).tolist(),
        payload={"description": text}
    )
]

qdrant.upload_points(
    collection_name="flights",
    points=points,
    batch_size=64,
    parallel=1,
    method=None,
    max_retries=3,
    wait=False
)

# %%
# Semantic search operations
query_vector = encoder.encode("Flight Duration").tolist()
hits = qdrant.search(
    collection_name="flights",
    query_vector=query_vector,
    limit=3
)
for hit in hits:
    print(hit.payload, "score:", hit.score)
# Out:
# {'description': 'Based on the analysis of the provided dataset, I conclude that to optimize pricing strategies, airlines should consider the following optimal price ranges for different departure date periods:\n\n**Winter Period (December 2023 to February 2024)**:\nThe optimal price range for this period is between 5953 and 5955, with a mean price of 5954.1. This is due to the lower demand during winter, resulting in lower prices.\n\n**Summer Period (June 2023 to July 2024)**:\nThe optimal price range for this period is between 5955 and 5956, with a mean price of 5955.5. This is due to the higher demand during summer, resulting in slightly higher prices.\n\nThe reasons for these optimal price ranges are attributed to the seasonal demand, school and holiday schedules, and weather and climate factors. By understanding these factors, airlines can adjust their pricing strategies to maximize revenue and respond to market fluctuations.\n\nTo achieve the highest profit, airlines should consider dynamic pricing, targeted promotions, and segmentation strategies. By doing so, they can capitalize on the seasonal demand and customer needs, ultimately leading to increased revenue and competitiveness in the market.\n\nIn conclusion, the optimal price ranges for different departure date periods are crucial in determining the pricing strategies of airlines. By understanding the relationship between departure dates and prices, airlines can refine their strategies to better respond to market fluctuations and customer needs, ultimately leading to increased revenue and competitiveness.'} score: 0.3769796
